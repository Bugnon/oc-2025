# %% [markdown]
# # Introduction to Jupyter Notebooks
#
# A Jupyter notebook allows to mix code and documentation in a single file.
# Here we have a variable definition and an expression.

# %%
x = 123
2 * x

# %% [markdown]
# ## Load a model
#
# `%pip` ensures the module is loaded in the same environment

# %%
# %pip install transformers accelerate huggingface_hub

# %% [markdown]
# ## Create text with GTP2
#
# This downloads the 548 MB model (.safetensor)
#
# - load language model (gtp2)
# - open settings (cmd+,)
# - search: notebook output word wrap

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator("Artificial intelligence will", max_length=30)

print(result[0]["generated_text"])

# %% [markdown]
# So were are the models stored ?
# - Qwen3-0.6B-Base (1.2 GB)
# - gtp2 (550 MB)

# %%
ls -l ~/.cache/huggingface/hub

# %% [markdown]
# ## Simple local chatbot

# %%
from transformers import pipeline

# load a conversational text model
chatbot = pipeline("text-generation", model="gpt2")

print("Mini Chatbot 🤖 (type 'exit' to stop)\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Bot: Goodbye!")
        break

    response = chatbot(user_input, max_length=60, num_return_sequences=1)

    print("Bot:", response[0]["generated_text"])

# %% [markdown]
# ## Using input()
#
# The function `input()` does does work, but it opens the input box at the top of the window.

# %%
x = input("Enter a number: ")
print( f"You entered: {x}" )

# %%
while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Bot: Goodbye!")
        break   
    user_input = input("You: ")
